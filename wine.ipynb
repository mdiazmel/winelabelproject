# %% [markdown]
# Reconstruction d'étiquettes de bouteilles de vin
# ==================================================
#
#
# # Part 1
#
# * Define the problem
#
#   ** Unwrap the label from a bottle wine. **
#   ** Goal: ** to reconstruct the shape of a bottle label
#   and its relative position to the camera, from a single image.
#
# <img src="./imgs/img1_s.jpg" />
#
# * Define which programming language and tools are the prefered
#
#   + Operating system
#     - Linux
#     - OsX (Mac)
#     - Windows
#   + Programming language
#     - Matlab
#     - Pyhton
#     - C/C++
#     - Other
#   + Tools
#     - Version control (git, svn)
#     - Github, bitbucket
#   + Others
#
# * Computer vision, Projective geometry
#
# * Ideas ?
#
#
#
# # Part 2
#
# * If python, use conda + scikit-image <http://scikit-image.org/>
#
# conda create -n wineLabel python=2.7 numpy  matplotlib pil pyqt scikit-image
#
# * If C/C++, use opencv
#
# Download, compile and install opencv
# <http://opencv.org/>
#
# * If Matlab
#
# Install Matlab
#
#
#
# # Part 3. Description generale de l'algorithme
#
# One aproach:
# In a 2D world the label is like that:
# <img src="./imgs/label.png" />
# But the representation of the scene in 3D world gives us this:
# <img src="./imgs/image.png" />
# We need to define a 3D world coordonate system, for exemple:
# <img src="./imgs/coordinates.png" />
#
# How to model camera and real world. We need to projet points from 3D worls into
# the camera plan.
# Projection matrix!
#
# $$ \mathsf{P} = \mathsf{K}  \mathsf{R} \begin{bmatrix} \mathsf{I} & -\mathbf{t} \end{bmatrix} $$
#
#
# # Part 4. Implementation en python
#
# Charger une image en python

# %%
# %pylab inline
# Out:
# /Users/mdiazmel/miniconda3/envs/wineLabel/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import misc
img = misc.imread('imgs/img1.jpg')
img = misc.imresize(img, 0.5)
img = img.astype(np.float) / 255.
plt.imshow(img)
type(img)
# Out:
# numpy.ndarray

# %% [markdown]
# Capture points from image (user input points)

# %%
# TODO

# %% [markdown]
# Reupérer les metadonnées

# %%
# TODO

# %% [markdown]
# Pas 1. Calcul des points de l'image callibres selon la matrice K

# %%
# TODO

# %% [markdown]
# Pas 2. Calcul des points de fuite

# %%
# TODO

# %% [markdown]
# Pas 3. Normalize au vector unite les vectors v1 et v2

# %%
# TODO

# %% [markdown]
# Pas 4. Calcul des solutions possibles pour R

# %%
# TODO

# %% [markdown]
# Pas 5. Calcul de la pose (t) et de la largeur de l'ettiquette (m)

# %%
# TODO

# %% [markdown]
# Pas 6. Calcul de la curvature de l'etiquette. Definition des matrices c c' et c''

# %%
# TODO

# %% [markdown]
# Recomposition de l'image et visualization

# %%
# TODO
